# %%
import pandas as pd
import numpy as np

# %%
train_merged=pd.read_csv('train_merged.csv')

# %%
train_merged[train_merged.click_times==1]
# Out:
#           creative_id    ad_id  product_id  product_category  advertiser_id  \
# 0                   1        1           0                 5            381
# 1               68590    63392           0                18          14681
# 2              127337   114621           0                18           9409
# 3              138157   124124          23                 2           9065
# 4              147066   132027           0                18          22918
# ...               ...      ...         ...               ...            ...
# 30082762      4146938  3557684        1261                 2          10988
# 30082763      4147704  3558343        1261                 2          10988
# 30082765      4204088  3606569        1261                 2          10988
# 30082766      4263153  3657208        1810                 2          61922
# 30082767      4291152  3680507        2400                 2          57709
#
# ...

# %%
predict_merged=pd.read_csv('predict_merged.csv')

# %%
predict_merged.describe()
# Out:
#         creative_id         ad_id    product_id  product_category  \
# count  3.358551e+07  3.358551e+07  3.358551e+07      3.358551e+07
# mean   1.674632e+06  1.446292e+06  3.922139e+03      8.125964e+00
# std    1.308090e+06  1.120606e+06  9.098822e+03      7.055398e+00
# min    1.000000e+00  1.000000e+00  0.000000e+00      1.000000e+00
# 25%    4.158050e+05  3.708990e+05  0.000000e+00      2.000000e+00
# 50%    1.506880e+06  1.309499e+06  1.290000e+02      3.000000e+00
# 75%    2.737762e+06  2.353237e+06  1.873000e+03      1.800000e+01
# max    4.445720e+06  3.812202e+06  4.431400e+04      1.800000e+01
#
#        advertiser_id      industry          time       user_id   click_times
# count   3.358551e+07  3.358551e+07  3.358551e+07  3.358551e+07  3.358551e+07
# mean    2.122169e+04  1.611937e+02  4.797323e+01  3.499714e+06  1.066196e+00
# std     1.408001e+04  1.290848e+02  2.593779e+01  2.883313e+05  3.561287e-01
# ...

# %%
pred_click_log=pd.read_csv("../test/click_log.csv")

# %%
pred_click_log["user_id"].nunique()
# Out:
# 1000000
